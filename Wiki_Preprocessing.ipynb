# %% [markdown]
# # Description of Notebook
#
# This notebook preprocesses and cleans the scrapped wikipedia pages to prepare them for generating Tf-Idf vector and Word embeddings

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
import string
import numpy as np
from collections import Counter

# %% [markdown]
# # Data loading

# %% [markdown]
# Load the scrapped wikipedia csv file

# %%
df = pd.read_csv('wiki.csv')

# %%
df
# Out:
#                       crime                                            content
# 0           Organized_crime  Organized crime is a category of transnational...
# 1             Violent_crime  A violent crime or crime of violence is a crim...
# 2          Money_laundering  \nMoney laundering is the illegal process of c...
# 3   International_sanctions  International sanctions are political and econ...
# 4       Terrorism_financing  Terrorism financing is the provision of funds ...
# 5        Illegal_drug_trade  The illegal drug trade or drug trafficking is ...
# 6      Political_corruption  \nPolitical corruption is the use of powers by...
# 7         Human_trafficking  \nHuman trafficking is the trade of humans  fo...
# 8           Sex_trafficking  Sex trafficking is human trafficking for the p...
# 9         Underground_poker  Underground poker is poker played in a venue t...
# 10                  Bribery  Bribery is defined by Black's Law Dictionary a...
# 11         Graft_(politics)  Graft, as understood in American English, is a...
# 12       Kickback_(bribery)  A kickback is a form of negotiated bribery in ...
# 13              Tax_evasion  Tax evasion is the illegal evasion of taxes by...
# 14          Insider_trading  Insider trading is the trading of a public com...
# 15         Securities_fraud  Securities fraud, also known as stock fraud an...
# 16          Corporate_crime  In criminology, corporate crime refers to crim...
# 17                    Fraud  \nIn law, fraud is intentional deception to se...
# 18           Internet_fraud  Internet fraud is a type of cybercrime fraud o...
# 19              Counterfeit  To counterfeit means to imitate something auth...
# 20                  Forgery  Forgery is a white-collar crime that generally...
# 21               Cybercrime  \nCybercrime, or computer-oriented crime, is a...
# 22                  Larceny  Larceny is a crime involving the unlawful taki...
# 23             Romance_scam  \nA romance scam is a confidence trick involvi...

# %% [markdown]
# # Pre-processing steps

# %% [markdown]
# Perform all the pre-processing steps such as lemmatizing, lower case conversion, removing stop words & punctuations

# %%
def lemmatize_stemming(data):
    """lemmatizes content of each wikipedia page"""
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + WordNetLemmatizer().lemmatize(w)
    return new_text

# %%
def convert_lower_case(data):
    """converts content of each wikipedia page into lower case"""
    return np.char.lower(data)

# %%
def remove_numbers(data):
    """removes numbers from the content of each wikipedia page"""
    data = str(data)
    new_text = ' '.join(s for s in data.split() if not any(c.isdigit() for c in s))
    return new_text

# %%
def remove_stop_words(data):
    """removes stop words from the content of each wikipedia page"""
    stop_words = stopwords.words('english')
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if w not in stop_words and len(w) > 1:
            new_text = new_text + " " + w
    return new_text

# %%
def remove_punctuation(data):
    """removes punctuations from the content of each wikipedia page"""
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in range(len(symbols)):
        data = np.char.replace(data, symbols[i], ' ')
        data = np.char.replace(data, "  ", " ")
    data = np.char.replace(data, ',', '')
    return data

# %%
def remove_apostrophe(data):
    """removes apostrophe from the content of each wikipedia page"""
    return np.char.replace(data, "'", "")

# %%
def preprocess(data):
    """single function that combines all the preprocessing functions
       You may notice that some functions are called more than once that is 
       beccause after lemmatizing step you may encounter few stop words again 
    """
    data = convert_lower_case(data)
    data = remove_numbers(data)
    data = remove_punctuation(data) 
    data = remove_apostrophe(data)
    data = remove_stop_words(data)
    data = lemmatize_stemming(data)
    data = remove_punctuation(data)
    data = lemmatize_stemming(data) 
    data = remove_punctuation(data) 
    data = remove_stop_words(data) 
    return data

# %% [markdown]
# add new column to the dataframe which contains cleaned content column

# %%
df['processed_content'] = df.content.apply(preprocess)

# %%
df
# Out:
#                       crime  \
# 0           Organized_crime
# 1             Violent_crime
# 2          Money_laundering
# 3   International_sanctions
# 4       Terrorism_financing
# 5        Illegal_drug_trade
# 6      Political_corruption
# 7         Human_trafficking
# 8           Sex_trafficking
# 9         Underground_poker
# 10                  Bribery
# 11         Graft_(politics)
# 12       Kickback_(bribery)
# 13              Tax_evasion
# 14          Insider_trading
# 15         Securities_fraud
# 16          Corporate_crime
# 17                    Fraud
# 18           Internet_fraud
# 19              Counterfeit
# 20                  Forgery
# 21               Cybercrime
# 22                  Larceny
# 23             Romance_scam
#
#                                               content  \
# 0   Organized crime is a category of transnational...
# 1   A violent crime or crime of violence is a crim...
# 2   \nMoney laundering is the illegal process of c...
# 3   International sanctions are political and econ...
# 4   Terrorism financing is the provision of funds ...
# 5   The illegal drug trade or drug trafficking is ...
# 6   \nPolitical corruption is the use of powers by...
# 7   \nHuman trafficking is the trade of humans  fo...
# 8   Sex trafficking is human trafficking for the p...
# 9   Underground poker is poker played in a venue t...
# 10  Bribery is defined by Black's Law Dictionary a...
# 11  Graft, as understood in American English, is a...
# 12  A kickback is a form of negotiated bribery in ...
# 13  Tax evasion is the illegal evasion of taxes by...
# 14  Insider trading is the trading of a public com...
# 15  Securities fraud, also known as stock fraud an...
# 16  In criminology, corporate crime refers to crim...
# 17  \nIn law, fraud is intentional deception to se...
# 18  Internet fraud is a type of cybercrime fraud o...
# 19  To counterfeit means to imitate something auth...
# 20  Forgery is a white-collar crime that generally...
# 21  \nCybercrime, or computer-oriented crime, is a...
# 22  Larceny is a crime involving the unlawful taki...
# 23  \nA romance scam is a confidence trick involvi...
#
#                                     processed_content
# 0    organized crime category transnational nation...
# 1    violent crime crime violence crime offender p...
# 2    money laundering illegal process concealing o...
# 3    international sanction political economic dec...
# 4    terrorism financing provision fund providing ...
# 5    illegal drug trade drug trafficking global bl...
# 6    political corruption use power government off...
# 7    human trafficking trade human purpose forced ...
# 8    sex trafficking human trafficking purpose sex...
# 9    underground poker poker played venue operatin...
# 10   bribery defined black law dictionary offering...
# 11   graft understood american english form politi...
# 12   kickback form negotiated bribery commission p...
# 13   tax evasion illegal evasion tax individual co...
# 14   insider trading trading public company stock ...
# 15   security fraud also known stock fraud investm...
# 16   criminology corporate crime refers crime comm...
# 17   law fraud intentional deception secure unfair...
# 18   internet fraud type cybercrime fraud deceptio...
# 19   counterfeit mean imitate something authentic ...
# 20   forgery white collar crime generally refers f...
# 21   cybercrime computer oriented crime crime invo...
# 22   larceny crime involving unlawful taking theft...
# 23   romance scam confidence trick involving feign...

# %% [markdown]
# Save the processed wikipedia file for further use

# %%
x.to_csv('processed_wiki.csv', index = False)
